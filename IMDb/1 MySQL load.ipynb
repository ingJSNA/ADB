# %% [markdown]
# # title_basics

# %%
title_basics = get_data.get_title_basics()
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult  startYear  endYear  runtimeMinutes                    genres
# 0        0     1894.0      NaN             1.0         Documentary,Short
# 1        0     1892.0      NaN             5.0           Animation,Short
# 2        0     1892.0      NaN             4.0  Animation,Comedy,Romance
# 3        0     1892.0      NaN             NaN           Animation,Short
# 4        0     1893.0      NaN             1.0              Comedy,Short

# %%
def tconst_transform(df):
    return df.str.replace('tt', '').astype(int)

title_basics_pre = title_basics.copy()
title_basics_pre['tconst'] = tconst_transform(title_basics_pre['tconst'])
title_basics_pre.head()
# Out:
#    tconst titleType            primaryTitle           originalTitle  isAdult  \
# 0       1     short              Carmencita              Carmencita        0
# 1       2     short  Le clown et ses chiens  Le clown et ses chiens        0
# 2       3     short          Pauvre Pierrot          Pauvre Pierrot        0
# 3       4     short             Un bon bock             Un bon bock        0
# 4       5     short        Blacksmith Scene        Blacksmith Scene        0
#
#    startYear  endYear  runtimeMinutes                    genres
# 0     1894.0      NaN             1.0         Documentary,Short
# 1     1892.0      NaN             5.0           Animation,Short
# 2     1892.0      NaN             4.0  Animation,Comedy,Romance
# 3     1892.0      NaN             NaN           Animation,Short
# 4     1893.0      NaN             1.0              Comedy,Short

# %%
# %%timeit -n 1 -r 1

save_dataFrame(title_basics_pre, 'title_basics')
# Out:
# Table title_basics deleted
# 3min 51s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# # title_akas

# %%
title_akas = get_data.get_title_akas()
title_akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1  Carmencita - spanyol tánc     HU      NaN
# 1  tt0000001         2                 Карменсита     RU      NaN
# 2  tt0000001         3                 Carmencita     US      NaN
# 3  tt0000001         4                 Carmencita    NaN      NaN
# 4  tt0000002         1     Le clown et ses chiens    NaN      NaN
#
#          types attributes  isOriginalTitle
# 0  imdbDisplay        NaN              0.0
# 1          NaN        NaN              0.0
# 2          NaN        NaN              0.0
# 3     original        NaN              1.0
# 4     original        NaN              1.0

# %%
title_akas_pre = title_akas.copy()
title_akas_pre['titleId'] = tconst_transform(title_akas_pre['titleId'])
title_akas_pre.head()
# Out:
#    titleId  ordering                      title region language        types  \
# 0        1         1  Carmencita - spanyol tánc     HU      NaN  imdbDisplay
# 1        1         2                 Карменсита     RU      NaN          NaN
# 2        1         3                 Carmencita     US      NaN          NaN
# 3        1         4                 Carmencita    NaN      NaN     original
# 4        2         1     Le clown et ses chiens    NaN      NaN     original
#
#   attributes  isOriginalTitle
# 0        NaN              0.0
# 1        NaN              0.0
# 2        NaN              0.0
# 3        NaN              1.0
# 4        NaN              1.0

# %%
# %%timeit -n 1 -r 1

save_dataFrame(title_akas_pre, 'title_akas')
# Out:
# Table title_akas deleted
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/pymysql/cursors.py in executemany(self, query, args)
# ...

# %%
# In[23]:


title_basics = get_title_basics()
title_basics.head()


# In[25]:


title_crew = get_title_crew()
title_crew.head()


# In[27]:


title_episode = get_title_episode()
title_episode.head()


# In[28]:


title_principals = get_title_principals()
title_principals.head()


# In[ ]:


title_ratings = get_title_ratings()
title_ratings.head()
