# %%
import pandas as pd
import sqlalchemy

import get_data

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://imdb:imdb@localhost:3306/imdb')

# %%
name_basics = get_data.get_name_basics()
name_basics.head()
# Out:
# File ./imdb/name.basics.tsv.gz already exists
# 176729080 176729080
# Warning, No downloading, the file ./imdb/name.basics.tsv.gz has the required size.
#       nconst      primaryName  birthYear  deathYear  \
# 0  nm0000001     Fred Astaire     1899.0     1987.0
# 1  nm0000002    Lauren Bacall     1924.0     2014.0
# 2  nm0000003  Brigitte Bardot     1934.0        NaN
# 3  nm0000004     John Belushi     1949.0     1982.0
# 4  nm0000005   Ingmar Bergman     1918.0     2007.0
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0037382,tt0038355,tt0117057,tt0071877
# 2     actress,soundtrack,producer  tt0059956,tt0049189,tt0054452,tt0057345
# 3         actor,writer,soundtrack  tt0078723,tt0080455,tt0077975,tt0072562
# 4           writer,director,actor  tt0050986,tt0083922,tt0050976,tt0060827

# %%
# nconst to int
name_basics['nconst'] = name_basics['nconst'].str.replace('nm', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c05a85a69cbf> in <module>
#       1 # nconst to int
# ----> 2 name_basics['nconst'] = name_basics['nconst'].str.replace('nm', '').astype(int)
#       3 name_basics.head()
#       4 name_basics.iloc[891]
#
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# ~/Programas/Miniconda3/envs/py3/lib/python3.6/site-packages/pandas/core/strings.py in _validate(data)
#    1915             # (instead of test for object dtype), but that isn't practical for
#    1916             # performance reasons until we have a str dtype (GH 9343)
# -> 1917             raise AttributeError("Can only use .str accessor with string "
#    1918                                  "values, which use np.object_ dtype in "
#    1919                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
name_basics.head()
# Out:
#    nconst      primaryName  birthYear  deathYear  \
# 0       1     Fred Astaire     1899.0     1987.0
# 1       2    Lauren Bacall     1924.0     2014.0
# 2       3  Brigitte Bardot     1934.0        NaN
# 3       4     John Belushi     1949.0     1982.0
# 4       5   Ingmar Bergman     1918.0     2007.0
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0037382,tt0038355,tt0117057,tt0071877
# 2     actress,soundtrack,producer  tt0059956,tt0049189,tt0054452,tt0057345
# 3         actor,writer,soundtrack  tt0078723,tt0080455,tt0077975,tt0072562
# 4           writer,director,actor  tt0050986,tt0083922,tt0050976,tt0060827

# %%
connection = engine.connect()
d = sqlalchemy.delete(sqlalchemy.table('name_basics'))
connection.execute(d)
connection.close()

name_basics.to_sql('name_basics', con=engine, if_exists='append', index=False, chunksize=1024*2)

# %%
# In[5]:


title_akas = get_title_akas()
title_akas.head()


# In[23]:


title_basics = get_title_basics()
title_basics.head()


# In[25]:


title_crew = get_title_crew()
title_crew.head()


# In[27]:


title_episode = get_title_episode()
title_episode.head()


# In[28]:


title_principals = get_title_principals()
title_principals.head()


# In[ ]:


title_ratings = get_title_ratings()
title_ratings.head()
